# %% [markdown]
# <a href="https://colab.research.google.com/github/yagnikta/pandas_basics/blob/main/pandas_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('weather.csv') # https://www.kaggle.com/datasets/zaraavagyan/weathercsv

"""

# TO BUILD THE DATAFRAME FROM THE PYTHON DICTIONARY

weather_data = {
    'day': ['1/1/2017', '1/2/2017', '1/3/2017'],
    'temperature': [32, 35, 28],
    'windspeed': [6, 7, 2],
    'event': ['Rain', 'Sunny', 'Snow']
}
df = pd.DataFrame(weather_data)

# TO BUILD THE DATAFRAME FROM THE PYTHON LIST OF TUPLES

weather_data = [
  ('1/1/2017', 32, 6, 'Rain'),
  ('1/2/2017', 35, 7, 'Sunny'),
  ('1/3/2017', 28, 2, 'Snow')
]
df = pd.DataFrame(weather_data, columns=['date', 'temperature', 'windspeed', 'event'])

# TO BULID THE DATAFRAME FROM THE PYTHON LIST OF DICTIONARIES

weather_data = [
  {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
  {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
  {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'}
]

df = pd.DataFrame(weather_data)

"""

df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
rows, columns = df.shape
print(rows, columns)
# Out:
# 366 22

# %%
df.head(4)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
# ...

# %%
df.tail(2)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 364       1021.0       1016.2         6         7     15.8     25.9
# 365       1009.6       1009.2         1         1     23.8     28.6
#
#      RainToday  RISK_MM RainTomorrow
# 364         No      0.0           No
# 365         No      0.0           No
#
# [2 rows x 22 columns]

# %%
df[2:5]
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 2       1009.5       1007.2         8         7     15.4     20.2        Yes
# 3       1005.5       1007.0         2         7     13.5     14.1        Yes
# 4       1018.3       1018.5         7         7     11.1     15.4        Yes
#
#    RISK_MM RainTomorrow
# 2     39.8          Yes
# 3      2.8          Yes
# 4      0.0           No
#
# ...

# %%
df[:]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
df.MinTemp
# Out:
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
#        ...
# 361     9.0
# 362     7.1
# 363    12.5
# 364    12.5
# 365    12.3
# Name: MinTemp, Length: 366, dtype: float64

# %%
df['MinTemp']
# Out:
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
#        ...
# 361     9.0
# 362     7.1
# 363    12.5
# 364    12.5
# 365    12.3
# Name: MinTemp, Length: 366, dtype: float64

# %%
type(df['MinTemp'])
# Out:
# pandas.core.series.Series

# %%
df[['MinTemp', 'Evaporation']]
# Out:
#      MinTemp  Evaporation
# 0        8.0          3.4
# 1       14.0          4.4
# 2       13.7          5.8
# 3       13.3          7.2
# 4        7.6          5.6
# ..       ...          ...
# 361      9.0          7.6
# 362      7.1         11.6
# 363     12.5          8.4
# 364     12.5          5.0
# 365     12.3          6.0
#
# [366 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['MinTemp'].plot(kind='hist', bins=20, title='MinTemp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Evaporation'].plot(kind='hist', bins=20, title='Evaporation')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
print(df['MinTemp'].min(),
df['MinTemp'].max(),
df['MinTemp'].sum(),
df['MinTemp'].mean(),
df['MinTemp'].std(),
df['MinTemp'].var())
# Out:
# -5.3 20.9 2659.2000000000003 7.265573770491804 6.025799834253392 36.3102636424882

# %%
df.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
df[['MinTemp' , 'MaxTemp']][df.MaxTemp == df.MaxTemp.max()]
df[['MinTemp', 'MaxTemp']][df.MinTemp == df.MinTemp.min()]
# Out:
#      MinTemp  MaxTemp
# 292     -5.3     13.1

# %%
df.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
df.loc[0] # Access by index
# Out:
# MinTemp             8.0
# MaxTemp            24.3
# Rainfall            0.0
# Evaporation         3.4
# Sunshine            6.3
# WindGustDir          NW
# WindGustSpeed      30.0
# WindDir9am           SW
# WindDir3pm           NW
# WindSpeed9am        6.0
# WindSpeed3pm         20
# Humidity9am          68
# Humidity3pm          29
# Pressure9am      1019.7
# Pressure3pm      1015.0
# Cloud9am              7
# Cloud3pm              7
# Temp9am            14.4
# Temp3pm            23.6
# RainToday            No
# RISK_MM             3.6
# RainTomorrow        Yes
# Name: 0, dtype: object

# %%
df.set_index('MinTemp')
# Out:
#          MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  WindGustSpeed  \
# MinTemp
# 8.0         24.3       0.0          3.4       6.3          NW           30.0
# 14.0        26.9       3.6          4.4       9.7         ENE           39.0
# 13.7        23.4       3.6          5.8       3.3          NW           85.0
# 13.3        15.5      39.8          7.2       9.1          NW           54.0
# 7.6         16.1       2.8          5.6      10.6         SSE           50.0
# ...          ...       ...          ...       ...         ...            ...
# 9.0         30.7       0.0          7.6      12.1         NNW           76.0
# 7.1         28.4       0.0         11.6      12.7           N           48.0
# 12.5        19.9       0.0          8.4       5.3         ESE           43.0
# 12.5        26.9       0.0          5.0       7.1          NW           46.0
# 12.3        30.2       0.0          6.0      12.6          NW           78.0
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df.set_index('WindDir9am', inplace=True)

# %%
df.loc['NW']
# Out:
#             index  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# WindDir9am
# NW             33     13.3     26.5       6.6          3.8      11.8
# NW             36     17.2     25.8       0.0          4.2       8.8
# NW             50     14.8     29.5       6.4          1.8       8.1
# NW             58     14.4     31.6       0.0          6.6      13.6
# NW             80     17.2     24.7      12.2          1.4       8.1
# NW             86     12.7     28.8       0.0          7.4       9.0
# NW             97     13.6     27.4       1.0          2.8       8.0
# NW            115     12.0     23.8       0.0         10.4      12.4
# NW            151      9.6     18.8       0.0          6.4      10.0
# NW            154      7.0     14.3       2.6          9.6       9.7
# NW            155      0.4     18.9       0.0          4.8       9.6
# NW            188      8.3     17.6       0.0          3.4       9.4
# ...

# %%
df.reset_index()
# Out:
#     WindDir9am  index  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0           SW      0      8.0     24.3       0.0          3.4       6.3
# 1            E      1     14.0     26.9       3.6          4.4       9.7
# 2            N      2     13.7     23.4       3.6          5.8       3.3
# 3          WNW      3     13.3     15.5      39.8          7.2       9.1
# 4          SSE      4      7.6     16.1       2.8          5.6      10.6
# ..         ...    ...      ...      ...       ...          ...       ...
# 361        SSE    361      9.0     30.7       0.0          7.6      12.1
# 362        NNW    362      7.1     28.4       0.0         11.6      12.7
# 363        ENE    363     12.5     19.9       0.0          8.4       5.3
# 364        SSW    364     12.5     26.9       0.0          5.0       7.1
# 365         NW    365     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir3pm  ...  Humidity3pm  Pressure9am  \
# ...
